# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
city_data = pd.read_csv("Berlin_data.csv")
global_data = pd.read_csv("global_data.csv")

# %%
city_data.head(10)
# Out:
#    year    city  country  avg_temp
# 0  1743  Berlin  Germany      6.33
# 1  1744  Berlin  Germany     10.36
# 2  1745  Berlin  Germany      1.43
# 3  1746  Berlin  Germany       NaN
# 4  1747  Berlin  Germany       NaN
# 5  1748  Berlin  Germany       NaN
# 6  1749  Berlin  Germany       NaN
# 7  1750  Berlin  Germany      9.83
# 8  1751  Berlin  Germany      9.75
# 9  1752  Berlin  Germany      4.84

# %%
global_data.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
city_data_considered = city_data[['year', 'avg_temp']][7:]
city_data_considered.reset_index(drop=True, inplace=True)

# %%
city_data_considered.head()
# Out:
#    year  avg_temp
# 0  1750      9.83
# 1  1751      9.75
# 2  1752      4.84
# 3  1753      8.72
# 4  1754      8.49

# %%
global_data.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
data_considered['city_MA'] = city_data_considered['avg_temp'].rolling(window=15).mean()
data_considered['global_MA'] = global_data['avg_temp'].rolling(window=15).mean()

# %%
city_data_considered['avg_temp'] .plot()

# %%
plt.plot(city_data_considered['year'], city_data_considered['city_MA'], label = 'City')
plt.plot(city_data_considered['year'], city_data_considered['global_MA'], label='Global')
plt.xlabel('Year')
plt.ylabel('avg_temp')
plt.title("Moving avergae for 15 years")
plt.legend()
# city_data_consi/dered

# %%
city_data_considered['diff_two'] = city_data_considered['avg_temp'] - global_data['avg_temp']

# %%
city_data_considered['diff_two'].rolling(window=5).mean().plot()

# %%
city_data_considered['city_diff'] = city_data_considered['avg_temp'].diff()
city_data_considered['global_diff']  = global_data['avg_temp'].diff()
plt.plot(city_data_considered['year'], city_data_considered['city_diff'], label = 'City', color ='red')
plt.plot(city_data_considered['year'], city_data_considered['global_diff'], label='Global')
plt.xlabel('Year')
plt.ylabel('avg_temp')
plt.title("differnce of temperature for city and global")
plt.legend()
# city_data_consi/dered

# %%
global_data['avg_temp'].diff().plot()

# %%
city_data_considered.head()
# Out:
#    year  avg_temp     MA
# 0  1750      9.83    NaN
# 1  1751      9.75    NaN
# 2  1752      4.84    NaN
# 3  1753      8.72    NaN
# 4  1754      8.49  8.326
